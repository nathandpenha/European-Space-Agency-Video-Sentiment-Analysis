# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
image1 = cv2.imread("content/tmpdir/vid_features/02-02-06-02-02-02-01-frame65.jpg")
image2 = cv2.imread("content/tmpdir/vid_features/02-02-06-02-02-02-01-frame70.jpg")

sub = cv2.subtract(image2, image1)


plt.subplot(2,2,1),plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))
plt.title('image 1'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.title('image 2'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(cv2.cvtColor(sub, cv2.COLOR_BGR2RGB))
plt.title('subtracted Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
image1 = cv2.imread("content/tmpdir/vid_features/02-02-06-02-02-02-01-frame65.jpg")
image2 = cv2.imread("content/tmpdir/vid_features/02-02-06-02-02-02-01-frame70.jpg")

sub = cv2.subtract(image2, image1)
add = cv2.add(image2, image1)

plt.subplot(2,2,1),plt.imshow(image1,cmap = 'gray')
plt.title('Original 1'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(image2,cmap = 'gray')
plt.title('Original 2'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sub,cmap = 'gray')
plt.title('sub Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(add)
plt.title('add Image'), plt.xticks([]), plt.yticks([])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-51cc9810234d> in <module>
#       5 add = cv2.add(image2, image1)
#       6
# ----> 7 plt.subplot(119),plt.imshow(image1)
#       8 plt.title('sub Image'), plt.xticks([]), plt.yticks([])
#       9 plt.subplot(120),plt.imshow(image2)
#
# d:\python_env\venv\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# d:\python_env\venv\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
# ...

# %%
img = cv2.imread("content/tmpdir/vid_features/02-02-06-02-02-02-01-frame10.jpg",0)
img = cv2.medianBlur(img,5)

ret,th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
            cv2.THRESH_BINARY,11,2)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
            cv2.THRESH_BINARY,11,2)

titles = ['Original Image', 'Global Thresholding (v = 127)',
            'Adaptive Mean Thresholding', 'Adaptive Gaussian Thresholding']
images = [img, th1, th2, th3]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.show()

# %%
img = cv2.imread("content/tmpdir/vid_features/02-02-06-02-02-02-01-frame10.jpg",0)
laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
img = cv2.imread("content/tmpdir/vid_features/02-02-06-02-02-02-01-frame10.jpg",0)
edges = cv2.Canny(img,100,200)

plt.subplot(121),plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])

plt.show()

# %%
img = cv2.imread("content/tmpdir/vid_features/02-02-06-02-02-02-01-frame10.jpg",0)
plt.hist(img.ravel(),256,[0,256]); plt.show()

img = cv2.imread("content/tmpdir/vid_features/02-02-06-02-02-02-01-frame10.jpg")
color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()
